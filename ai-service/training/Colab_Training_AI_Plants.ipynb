# %% [markdown]
# # 🌿 AI Plants - Panduan Training Otomatis
# Buku catatan (*notebook*) ini dirancang agar Anda bisa melatih ulang model AI kapan saja Anda memiliki data gambar tanaman baru.

# %% [markdown]
# ### Langkah 1: Hubungkan ke Google Drive
# Ini agar Colab bisa mengambil file dataset Anda (seperti dataset_jagung.zip) dan menyimpan hasil AI ke tempat yang aman.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Langkah 2: Unduh Kode AI Plants Anda dari GitHub
# Kita perlu mengunduh file 	rain.py agar tidak perlu menulis ulang kode.

# %%
# !rm -rf AI-Plants
# !git clone https://github.com/Wahyu1011/AI-Plants.git
# %cd AI-Plants/ai-service/training

# %% [markdown]
# ### Langkah 3: Ekstrak Dataset Anda dari Google Drive
# Ubah dataset_baru.zip dengan nama file ZIP dataset Anda yang ada di Google Drive. Jika Anda punya lebih dari satu file, Anda bisa meng-copy baris unzip menjadi beberapa baris.

# %%
# CONTOH:
# !unzip -o '/content/drive/MyDrive/dataset_padi.zip' -d 'dataset'
# !unzip -o '/content/drive/MyDrive/dataset_jagung.zip' -d 'dataset'
# !unzip -o '/content/drive/MyDrive/dataset_tomat.zip' -d 'dataset'

# %% [markdown]
# ### Langkah 4: Mulai Proses Pelatihan (Training)!
# Jalankan sel ini dan tunggu hingga selesai. Waktu yang dibutuhkan tergantung seberapa banyak gambar yang Anda masukkan.

# %%
# !python train.py

# %% [markdown]
# ### Langkah 5: Amankan Hasil AI Anda
# Pindahkan otak AI (plant_disease_model.h5) ke Google Drive agar bisa Anda unduh dan masukkan ke website Anda.

# %%
import shutil
shutil.copy('plant_disease_model.h5', '/content/drive/MyDrive/plant_disease_model_terbaru.h5')
print('Selesai! Model berhasil disimpan ke Google Drive Anda.')
